# %% [markdown]
# We have learned that problem working with the text mode file is there we actually can't store any other type of data except the string.
# So, we can't store the list, dictionary, or any other type of data in the text mode file.
#
# But, we can store the list, integer, float, dictionary, or any other type of data in the binary mode file because in the binary mode file we can store any type of data in the file.
# We can store the list, dictionary, integer, float, or any other type of data in the file using serialization and deserialization in the binary mode file in python.
#
# # Serialization and Deserialization :
#
# Serialization - process of converting python data types to JSON format
#
# Deserialization - process of converting JSON to python data types
#
#
# #### What is JSON?
#
# The full form of JSON is JavaScript Object Notation.
#
# JSON is just a file format that is used to store the data in the file. JSON is a string format. JSON is a lightweight data interchange format. It is easy for humans to read and write. It is easy for machines to parse and generate. It is based on a subset of the JavaScript Programming Language Standard ECMA-262 3rd Edition - December 1999.
#
# So in '.txt' file we can store only string data but in JSON file we can store any type of data like list, dictionary, integer, float, etc. So, we can store any type of data in the JSON file.
# Format of JSON file is '.json' file.
#
# JSON is a text format that is completely language independent but uses conventions that are familiar to programmers of the C-family of languages, including C, C++, C#, Java, JavaScript, Perl, Python, and many others. These properties make JSON an ideal data-interchange language.
#
# **JSON is built on two structures:**
#
# 1. A collection of name/value pairs. In various languages, this is realized as an object, record, struct, dictionary, hash table, keyed list, or associative array.
# 2. An ordered list of values. In most languages, this is realized as an array, vector, list, or sequence.
#
# These are universal data structures. Virtually all modern programming languages support them in one form or another. It makes sense that a data format that is interchangeable with programming languages also be based on these structures.
#
# **JSON is similar to python dictionary. We can convert the python dictionary to JSON and JSON to python dictionary. JSON is a string format and python dictionary is a python data type so we can't store the python dictionary in the file. But we can store the JSON in the file because JSON is a string format.**
#
# ![image.png](attachment:image.png)
#
#
# **Why we use JSON for serialization and deserialization in python file , why not other format?**
# =>
# - Because JSON is a universal file format that can be used in any programming language and it is easy to read and write the data in JSON format.
# - Because JSON can support all the programming languages like C, C++, Java, JavaScript, Perl, Python, and many others.
# - All the websites and web applications in the world are using JSON format for reading the data , store the data , whenever we will be doing the API call , when ever we are getting the response from the API call , we are getting the response in the JSON format.
#
# **- Every things we see the internet can support the JSON format** like web applications, websites, API calls, data interchange, data transfer, data storage, etc. So, we are using the JSON format for serialization and deserialization in the python file.
#
#
# **In future project of python we use .json file for storing any data :**
#     If we want to store any type of data in python projects then we can store the data in the JSON file because JSON is a universal file format that can be used in any programming language and it is easy to read and write the data in JSON format. So, we can store any type of data in the JSON file like list, dictionary, integer, float, etc.
#     That's why we are using the JSON file for serialization and deserialization in the python file.
#     '.json' file is the extension of the JSON file.

# %%
## Serialization using json module in python :
