# %% [markdown]
# # Encapsulation in OOP (Python)
#
# - We have  learned class and object already and now we are going to learn about Encapsulation in OOP then , after encapsulation in next video we will learned about polymorphism , inheritance, Abstraction and so on.
#
# - We’ll using one story to explain this Encapsulation concept because it is complete practical understanding . So, let’s go to the our code editor and try to understand what is Encapsulation inside OOP ?
#
# Encapsulation is a fundamental object-oriented principle in Python. It protects your **classes** from accidental changes or deletions and promotes code reusability and maintainability.
#
# Encapsulation is capsule or wrapping of data (variables) and methods (functions) into a single unit called a **class**. It is a way to restrict access to some of the object's components.
#
# **Exercise :**

# %%
class Atm:

    #constructor(special function) - superpower
    def __init__(self):
        self.pin = ""
        self.balance = 0  # class variable
        # self.menu()


    def menu(self):
        user_input = input(
            """
            Hi how can i help you?

            1. Press 1 to create pin
            2. Press 2 to change pin
            3. Press 3 to check balence
            4. Press 4 to withdraw
            5. Anything to exit
            """
        )

        if user_input == '1':
            #create a pin
            self.create_pin()

        elif user_input == '2':
            #change pin
            self.change_pin()

        elif user_input == '3':
            #check balnce
            self.check_balance()

        elif user_input == '4':
            #withdraw
            self.withdraw()

        else:
            exit()


    def create_pin(self):
        user_pin = input("Enter your pin: ")
        self.pin = user_pin

        user_balance = int(input("Enter Balance: "))
        self.balance = user_balance

        print("Pin Created Successfully!")
        # self.menu()


    def change_pin(self):
        old_pin = input("Enter old pin: ")

        if old_pin == self.pin:
            #Let change the pin
            new_pin = input("Enter new pin: ")
            self.pin = new_pin
            print("Pin changed Successfully!")
            # self.menu()

        else:
            print("Sorry you entered wrong pin.")
            # self.menu()




    def check_balance(self):
        user_pin = input("Enter your pin: ")
        if user_pin == self.pin:
            print(f"Your balance is {self.balance}")
        else:
            print("Your pin is correct, please try again")
        # self.menu()



    def withdraw(self):
        user_pin = input("Enter your pin: ")
        if user_pin == self.pin:
            # Allow to withdraw
            amount = int(input("Enter the amount: "))
            if amount <= self.balance:
                self.balance = self.balance - amount
                print(f"withdraw successfull and the current balance is {self.balance}")

            else:
                print("You have insufficient balance")


        else:
            print("Your pin is wrong!")
        # self.menu()

# %% [markdown]
# In the above code I have commented the calling the menu function line of code because I don't want to automatically get the menu function right now. I will call the menu function when I need it and here I'm going to call these functions one by one that's why I have commented the menu function line of code in the above code. So, that when I'll execute the code it will not automatically call the menu function.
#
#
# # Real Life Example of Encapsulation implementation in Python :
#
# Let's say **I am working in a company** and I am working as a **senior developer**. So, We know **senior developers write** any kinds of **function** or write any kinds of **class**. Let's say I have written this particular class called ATM in above code.
#
# So, I have a project and Inside project we have to implement ATM machine code functionality. So, It is my responsibility to design this particular class called ATM. So, I have designed this class called ATM and everything is working fine. We have tested this class and everything is working fine. Here, we can create the pin and we can change the pin and we can withdraw the money. Everything is working fine.
#
# After implementing this ATM class, I'll try to handover this class to my junior developer. So, What junior developer will try to do is junior developer will try to integrate this functionality in the actual ATM machine or in the actual website and this task is given to junior developer.
#
# So, As a senior programmer , I have to design the code module always or class. This is always happens in all the industry that senior developer always design the code module or class and junior developer always integrate the code module or class in the actual project or software or website. Because our company won't be giving the responsibility to implement the code functionality to junior developer. Because junior developer doesn't have that much experience. So, that's why senior developer always design the code module or class and junior developer always integrate the code module or class in the actual project or software or website.
#
# That's why as a **senior programmer it's my responsibility to maintain this particular class itself** and after implementation **senior developer will handover this class to junior developer** and **junior developer will try to test it , whether it is working fine or not.** If it is not working fine then junior developer will give the feedback to senior developer and senior developer will try to fix the issue and again handover the class to junior developer. And after that **junior developer will integrate this class in the actual project or software or website.**
#
#
#
# #### Example :
# Let's say inside our company there is a junior programmer and he is like very clever and he's like very crazy. let's say he is thinking sir has given me this particular class , now what he will try do find out one mistake I have done and I will get fired from the company. let's say these kinds of thought actually he is having . So what he will do , let's say I have given ATM class to the junior programmer. Now as a junior programmer what he will do :
#
# 1) First of all he will initialize a object first of all.
#
# ```python
# obj = Atm()
# ```
#
# 2) now he'll just to give data to the balance variable. If we execute this code then it will work fine. We can create and access class variable outside the class. It is possible in python. We can store anythings inside the class variable.
#
# ```python
# obj.balance = "hello"
# ```
#
# 3) Now If he try to check the balance then it will give the output as "hello". So, he can access the class variable outside the class.
#
# ```python
# obj.check_balance()
# ```
# ```output
# Your balance is hello
# ```
#
# - so, this is the problem, Our balance should be integer but he has given the string value to the balance variable and he can access the class variable outside the class. So, this is the problem.
#
# 4) Now if he try to withdraw the money then, there will be an error because we have given the string value to the balance variable.
#
# ```python
# obj.withdraw()
# ```
# ```output
# TypeError: '<=' not supported between instances of 'int' and 'str'
# ```
#
# Now, This is throwing an error because we have given the string value to the balance variable and we can access the class variable outside the class. So, this is the problem.
#
# Now, my manager will come and manager will blame me because I am a senior programmer and say's what kinds of code you have written because it is failing in the production and that time actually he will fire me from the company because as a senior developer if I am writing these kinds of code then it is not good. No one will give me another chance. So, junior developer can do some crazy things in our code and he will get the promotion.
#
# **That is where actually encapsulation concept comes into the picture.** Encapsulation means there is a concept inside OOP called **private variable and private method.** So, we can make the variable private and we can make the method private. So, **that no one can access the variable outside the class.** So, that is the concept of encapsulation.
#
# If we want to protect our sensitive variable from outside the class then we can make the variable private. So, that no one can access the variable outside the class.
#
#
#
# #### Q) How we can define a private variable in python ?
#
# Instead of using the variable like before , **we can use like positive sign or negative sign before the variable name.** So, that it will become private variable. When we use the positive sign before the variable name then it will become public variable and when we use the negative sign before the variable name then it will become private variable.
#
# ```python
# class Atm:
#     def __init__(self):
#         self._balance = 0     # using negative sign before the variable name to make it private variable.
# ```
#
# Now, If I want to make anything private inside class then I have to use this double underscore before the variable name. So, that it will become private variable.
#
# ```python
# class Atm:
#     def __init__(self):
#         self.__balance = 0     # using double underscore before the variable name to make it private variable.
# ```
#
# **Exercise :**

# %%
class Atm:

    #constructor(special function) - superpower
    def __init__(self):
        self.pin = ""
        self.__balance = 0  # private variable
        # self.menu()


    def __menu(self):      # private method
        user_input = input(
            """
            Hi how can i help you?

            1. Press 1 to create pin
            2. Press 2 to change pin
            3. Press 3 to check balence
            4. Press 4 to withdraw
            5. Anything to exit
            """
        )

        if user_input == '1':
            #create a pin
            self.create_pin()

        elif user_input == '2':
            #change pin
            self.change_pin()

        elif user_input == '3':
            #check balnce
            self.check_balance()

        elif user_input == '4':
            #withdraw
            self.withdraw()

        else:
            exit()


    def __create_pin(self):       # private method
        user_pin = input("Enter your pin: ")
        self.pin = user_pin

        user_balance = int(input("Enter Balance: "))
        self.__balance = user_balance     # private variable

        print("Pin Created Successfully!")
        # self.menu()


    def change_pin(self):
        old_pin = input("Enter old pin: ")

        if old_pin == self.pin:
            #Let change the pin
            new_pin = input("Enter new pin: ")
            self.pin = new_pin
            print("Pin changed Successfully!")
            # self.menu()

        else:
            print("Sorry you entered wrong pin.")
            # self.menu()




    def check_balance(self):
        user_pin = input("Enter your pin: ")
        if user_pin == self.pin:
            print(f"Your balance is {self.balance}")
        else:
            print("Your pin is correct, please try again")
        # self.menu()



    def withdraw(self):
        user_pin = input("Enter your pin: ")
        if user_pin == self.pin:
            # Allow to withdraw
            amount = int(input("Enter the amount: "))
            if amount <= self.balance:
                self.balance = self.balance - amount
                print(f"withdraw successfull and the current balance is {self.balance}")

            else:
                print("You have insufficient balance")


        else:
            print("Your pin is wrong!")
        # self.menu()

# %% [markdown]
# In the above code where ever we have written the balance variable, I'll just change it with the double underscore. So, that it will become private variable. After executing the above code, If I try to access the balance variable outside the class then it will give the error.
#
# I will again define the object of this ATM machine , now if our junior programmer define the object and press the dot , again he will able to see all the variables and methods we have defined inside the class. Now, junior programmer see double underscore balance variable so our junior programmer is know that our senior programmer has made the balance variable private. So, he can't access the balance variable outside the class.
#
# If our junior programmer again try to change in the private variable which is created by senior programmer then
#
# ```python
# obj = Atm()
# ```
#
# ```python
# obj.create_pin()
# ```
# ```output
# Pin Created Successfully
# ```
#
# ```python
# obj.__balance = "Hello"
# ```
#
# ```python
# obj.check_balance()
# ```
# ```output
# Your balance is 4000
# ```
#
# **Now, If junior programmer try to check the balance then it will give the output as 4000 because he has given the string value to the balance variable but it is not showing the string value because we have made the balance variable private. So, he can't access the balance variable outside the class. Because changing the private variable is not possible in python and it is not showing the string value.**
#
#
#
# ###### But we have one question why **obj.__balance = "Hello"** is executing successfully ?
# =>
#
# Because we have made the balance variable private but we can access the private variable outside the class. but we can't change the private variable outside the class. So, we can access the private variable outside the class but we can't change the private variable outside the class.
#
# ###### what is happening whenever we are creating a private property inside a class ?
# =>
#
# Let's say I have created **__balance = 0** variable inside the class or created private methods. So, what python will do is python will create a new variable called **_Atm__balance = 0**. So, python will create a new variable with the class name and variable name.
#
# So, after creating the private variable, python will automatically create a new variable with the class name and variable name. So, that's why we can access the private variable outside the class but we can't change the private variable outside the class.
#
# Here, junior programmer is not able to change the private variable but he can access the private variable outside the class. now he is creating a new variable name in the memory or in the class.
#
#
# #### Again, If our junior programmer still didn't give up and what he will do ?
# =>
# Now junior programmer actually know that **obj __balance** is not an actual way to change anything inside a variable . So, junior programmer know that if he want to change the variable then he need to call with **_Atm__balance** variable name.
#
# 1) now he'll just to give data to the balance variable. If we execute this code then it will work fine. We can create and access class variable outside the class. It is possible in python. We can store anythings inside the class variable.
#
# ```python
# obj._Atm__balance = "hello"
# ```
#
# 2) Now If he try to check the balance then it will give the output as "hello". So, he can access the class variable outside the class.
#
# ```python
# obj.check_balance()
# ```
# ```output
# Your balance is hello
# ```
#
# - so, this is the problem, Our balance should be integer but he has given the string value to the balance variable and he can access the class variable outside the class. So, this is the problem.
#
# 3) Now if he try to withdraw the money then, there will be an error because we have given the string value to the balance variable.
#
# ```python
# obj.withdraw()
# ```
# ```output
# TypeError: '<=' not supported between instances of 'int' and 'str'
# ```
#
# Now, This is throwing an the same error because we have given the string value to the balance variable and we can access the class variable outside the class. So, this is the problem.
#
#
# #### So , What is the use of the private variable in python ?
# =>
# Because still my junior programmer can change anything inside the private variable. So, in other programming language it's not possible once we have define something in private property , we will die but we can't change that particular property. We can't change any kinds of value inside that private property. But in python we can change the value inside the private property. **Although it was the private property but with the help of these particular hack we can change the value inside the private property.** because we know in memory how my private property is getting created and if we know that particular name , we can easily change something in that variable , We have already proven that.

# %%
## In Python nothing is too private
# it is made for adults

# %% [markdown]
# So, Whenever we are working in the industry as a senior programmer then and if we're using any kinds of private property then our junior programmer have the responsibility . So, that junior programmer won't be changing anything inside the private property. This is called actually adultness. These kinds of adultness our junior programmer should have. If junior programmer doesn't have that means there is a definitely some issue with our company culture. So, that's why we have to maintain the adultness in our company.
#
# If we doesn't accidently change the private variable inside the **class variable or class methods** then we can use this encapsulation concept that means we can use private property that time.
#
#
# So, Whenever we see the double underscore before the variable name or method name then we have to consider that it is a private property or private method and I don't need to change anything inside the private property or private method because it's not recommended because python is made for adult person. So, as a programmer we have to maintain the adultness.
#
#
#
# #### If some cases actually it is required to change something inside a private property , let's say we are creating the application and there is a condition we have to change something inside the private property then what we can do ?
# =>
# At that time as a senior programmer we won't be allowing the junior programmer or telling our junior programmer to call the object and change the private variable. We as senior programmer won't be giving these kinds of suggestion to junior programmer.
# Instead of that what we will do ? => We will use another concept inside encapsulation called **getter and setter method**. So, that we can change the value inside the private property.
#
# In the next video we will learn about getter and setter method inside encapsulation concept. So, that we can change the value inside the private property. These are the recommended way to change the value inside the private property as a senior programmer.
# As a senior programmer if we want to change the value inside the private property ourself or we want to give the permission to junior programmer to change the value inside the private property or public property then we have to use the getter and setter method.
#
#
# So, Whenever we are creating software or create any kinds of project and if we are using any sensitive variable or sensitive function, so make sure we're using these private or public symbol before the variable name or method name. So, that no one can change the value inside the private property or private method.
#
# No need to make every thing public otherwise what will happen they will directly able to change our variable or function. So, make sure we're using the private property or private method. So, that no one can change the value inside the private property or private method.
# So, instead of reflecting in the actual private variable , it will create a new variable inside the class. Until and unless junior programmer not calling in that way because junior programmer won't be calling in that way because he is a adult programmer and he knows that this is the private property , he don't need to change anything inside the private property. So, that's why he won't be calling in that way. This the concept of encapsulation in OOP.
#
#
# **So, in next video we'll learn, if we want to change something in the private property then we have to use the getter and setter method. So, that we can change the value inside the private property. These are the recommended way to change the value inside the private property as a senior programmer.**
